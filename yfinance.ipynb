# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import yfinance as yf

# %%
ticker="tsla"
df=yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
df.shape
# Out:
# (3067, 6)

# %%
df.info()
plt.plot(df.Close)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3067 entries, 2010-06-29 to 2022-09-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3067 non-null   float64
#  1   High       3067 non-null   float64
#  2   Low        3067 non-null   float64
#  3   Close      3067 non-null   float64
#  4   Adj Close  3067 non-null   float64
#  5   Volume     3067 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 167.7 KB

# %%
from matplotlib.pyplot import figure
figure(figsize=(18,6),dpi=80)
plt.plot(df.Close)

# %%
start="2021-08-31"
end="2022-08-31"

# %%
df1=yf.download(ticker,start=start,end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df["index"]=df.index
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#                 index
# Date
# 2010-06-29 2010-06-29
# 2010-06-30 2010-06-30
# 2010-07-01 2010-07-01
# 2010-07-02 2010-07-02
# 2010-07-06 2010-07-06

# %%
figure(figsize=(18,6),dpi=80)

plt.plot(df.index,df.Close) 
plt.xlabel("Time duration", fontweight='bold')
plt.ylabel("Price", fontweight='bold') 
ax = plt.axes()

ax.set_facecolor('white')
plt.plot(df.Close)
plt.show()

# %%
from matplotlib.pyplot import figure
figure(figsize=(18,9))
plt.plot(df1.Close)
plt.show()

# %%
df1["index"]=df1.index

# %%
df1.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-08-30  238.240005  243.666672  237.576660  243.636673  243.636673
# 2021-08-31  244.333328  246.796661  242.146667  245.240005  245.240005
# 2021-09-01  244.693329  247.330002  243.756668  244.696671  244.696671
# 2021-09-02  244.833328  246.990005  243.513336  244.130005  244.130005
# 2021-09-03  244.083328  244.666672  241.399994  244.523331  244.523331
#
#               Volume      index
# Date
# 2021-08-30  55812600 2021-08-30
# 2021-08-31  62566200 2021-08-31
# 2021-09-01  39612900 2021-09-01
# 2021-09-02  38331900 2021-09-02
# 2021-09-03  45738300 2021-09-03

# %%
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-08-26  297.429993  302.000000  287.470001  288.089996  288.089996
# 2022-08-29  282.829987  287.739990  280.700012  284.820007  284.820007
# 2022-08-30  287.869995  288.480011  272.649994  277.700012  277.700012
# 2022-08-31  280.619995  281.250000  271.809998  275.609985  275.609985
# 2022-09-01  272.575012  275.839996  268.350006  268.545502  268.545502
#
#               Volume
# Date
# 2022-08-26  56905800
# 2022-08-29  41864700
# 2022-08-30  50541800
# 2022-08-31  51788900
# 2022-09-01  18371469

# %%
df2=yf.download(ticker,period="max",interval="3mo")
figure(figsize=(18,9))
plt.plot(df2.Close)
# Out:
# [*********************100%***********************]  1 of 1 completed
