# %%
import pandas as pd
df=pd.read_csv(r"D:\data science\python\pandas python\5. London Housing Data.csv")

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# ...
#      -------------------------------------- 292.8/292.8 kB 3.6 MB/s eta 0:00:00
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.date=pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
df["year"]=df.date.dt.year
df["month"]=df.date.dt.month
#df.insert(2,"month",df.date.dt.month)

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year  month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %%
df.drop(["month","year"],axis=1,inplace=True)

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df[df.no_of_crimes == 0].count()
# Out:
# date             104
# area             104
# average_price    104
# code             104
# houses_sold      104
# no_of_crimes     104
# dtype: int64

# %%
df["year"]=df.date.dt.year
df1=df[df.area=='england']
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
df1.groupby("year").min()
# Out:
#            date     area  average_price       code  houses_sold  no_of_crimes
# year
# 1995 1995-01-01  england          52788  E92000001      47639.0           NaN
# 1996 1996-01-01  england          52333  E92000001      48694.0           NaN
# 1997 1997-01-01  england          55789  E92000001      66246.0           NaN
# 1998 1998-01-01  england          61659  E92000001      61036.0           NaN
# 1999 1999-01-01  england          65522  E92000001      59989.0           NaN
# 2000 2000-01-01  england          75219  E92000001      68031.0           NaN
# 2001 2001-01-01  england          84245  E92000001      64870.0           NaN
# 2002 2002-01-01  england          96215  E92000001      71678.0           NaN
# 2003 2003-01-01  england         121610  E92000001      75657.0           NaN
# 2004 2004-01-01  england         139719  E92000001      79540.0           NaN
# 2005 2005-01-01  england         158572  E92000001      53464.0           NaN
# ...

# %%
df1.groupby("year").average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
df.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
#df.groupby("area").max()
df.groupby("area").no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
df[df.average_price<100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
