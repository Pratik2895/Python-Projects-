# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 3.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 2.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 957.2/957.2 kB 4.6 MB/s eta 0:00:00
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
df=pd.read_csv(r"D:\data science\python\pandas python\2. Cars Data1.csv")

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
df.shape
# Out:
# (432, 15)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
l=['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice','EngineSize','Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
       'Weight', 'Wheelbase', 'Length']
v=[3.196728971962617, 5.807511737089202, 215.8855140186916, 20.060747663551403, 26.843457943925234, 3577.9532710280373, 108.15420560747664, 186.36214953271028]
df['EngineSize'].fillna(df['EngineSize'].mean(),inplace=True)

# %%
df['Cylinders'].fillna(df['Cylinders'].mean(),inplace=True)

# %%
df['Horsepower'].fillna(df['Horsepower'].mean(),inplace=True)

# %%
df['MPG_City'].fillna(df['MPG_City'].mean(),inplace=True)

# %%
df['MPG_Highway'].fillna(df['MPG_Highway'].mean(),inplace=True)

# %%
df['Weight'].fillna(df['Weight'].mean(),inplace=True)

# %%
df['Wheelbase'].fillna(df['Wheelbase'].mean(),inplace=True)

# %%
df['Length'].fillna(df['Length'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df['Make'].fillna(df['Make']=='Make',inplace=True)
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df['Model'].fillna(df['Model']=='Model',inplace=True)
df['Type'].fillna(df['Type']=='Type',inplace=True)
df['Origin'].fillna(df['Origin']=='Origin',inplace=True)
df['DriveTrain'].fillna(df['DriveTrain']=='DriveTrain',inplace=True)
df['MSRP'].fillna(df['MSRP']=='MSRP',inplace=True)
df['Invoice'].fillna (df['Invoice']=='Invoice',inplace=True)

# %%
df['Make'].value_counts()
df['Origin'].unique()
# Out:
# array(['Asia', 'Europe', False, 'USA'], dtype=object)

# %%
df[(df['Origin']=="Asia")|(df['Origin']=='USA')]
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %%
df[df['Origin'].isin(["Asia","USA"])]
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %%
df[~(df["Weight"]>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df['MPG_City']=df['MPG_City'].apply(lambda x:x+3)

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
